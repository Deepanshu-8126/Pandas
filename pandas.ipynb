# %%
# PANDAS
import numpy as np
import pandas as pd

# %%
# series from lists

# string
country = ['India','Pakistan','USA','Nepal','Srilanka']

pd.Series(country)
# in series a index and value here india assign the value india -0
# dtype = object means this is a string
# series there are two things values and index
# Out:
# 0       India
# 1    Pakistan
# 2         USA
# 3       Nepal
# 4    Srilanka
# dtype: object

# %%
# integers ( we want to store batsman data this is in the form of integers)
runs=[13,24,56,78,100]

# we want to store this is in series
print(pd.Series(runs))

# dtype = int64
# Out:
# 0     13
# 1     24
# 2     56
# 3     78
# 4    100
# dtype: int64

# %%
# CUSTOM INDEX (we can provide index)
marks=[67,57,89,100]
subjects=['maths','english','science','social science']

pd.Series(marks,index=subjects)
# Out:
# maths              67
# english            57
# science            89
# social science    100
# dtype: int64

# %%
# setting a name (Means we can give a name to series object)

marks=pd.Series(marks,index=subjects,name='Deepanshu Marks')
print(marks)
# Out:
# maths              67
# english            57
# science            89
# social science    100
# Name: Deepanshu Marks, dtype: int64

# %%
# Series from dictionary

calories={"day":420,"day2":380,"day3":390}
my_var=pd.Series(calories) # pass dictionary
print(my_var)
print(my_var.loc["day2"])
print(my_var.loc["day3"])
# Out:
# day     420
# day2    380
# day3    390
# dtype: int64
# 380
# 390

# %%
# example--
marks={"deepanshu":56,"Himanshu":56,"vishal":65}
marks_=pd.Series(marks,name="Student marks")
print(marks_)
# Out:
# deepanshu    56
# Himanshu     56
# vishal       65
# Name: Student marks, dtype: int64

# %% [markdown]
# Series Attributes

# %%
# size -- total items
marks_.size
# Out:
# 3

# %%
# dtype (typee of data in our series)
marks_.dtype
# Out:
# dtype('int64')

# %%
# 3-- name
marks_.name
# output -- student marks
# Out:
# 'Student marks'

# %%
# is_unique (repeat or not return true )
marks_.is_unique
print(marks_.is_unique)

# create a series
series=pd.Series([1,1,2,2,3,4,5,6])
print(series.is_unique) # false duplicates
# Out:
# False
# False

# %%
# 4--index ( return index ( index object ))
marks_.index

print(series.index) # return range index
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %%
# 5 - values ( return values all in our series as an numpy array)
print(marks_.values)
print(series.values)
# Out:
# [56 56 65]
# [1 1 2 2 3 4 5 6]

# %% [markdown]
# SERIES USING READ_CSV

# %% [markdown]
# using dataset uploading csv file comma separated values ( series object create using  read csv read csv files )

# %%
# uplod three csv files subs.csv bollywood.csv kohli.pl.csv
# 1 -subs.csv
# how to read ( path copy and paste it under brackets )

pd.read_csv('/content/subs.csv') # stores in the format dataframe by default
# after runing this is not a series
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
# convert  to series ( paramter squueze = TRUE)
# dataframe

df=pd.read_csv("/content/subs.csv")
s=df.squeeze()
print(type(s))
print(s)
# truncated data
# Out:
# <class 'pandas.core.series.Series'>
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
# 2- csv file load

df=pd.read_csv('/content/kohli_ipl.csv',index_col='match_no')
vk=df.squeeze()
print(vk)
print(type(vk))
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64
# <class 'pandas.core.series.Series'>

# %%
# 3-- csv filee upload (name object name lead)

df=pd.read_csv('/content/bollywood.csv',index_col='movie',)
movies=df.squeeze()
print(movies)
print(type(movies))
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object
# <class 'pandas.core.series.Series'>

# %%
# series methods
# head and tail ( preview return )
print(movies.head())
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
# Name: lead, dtype: object

# %%
# tail ( last five rows)
print(movies.tail())
# Out:
# movie
# Hum Tumhare Hain Sanam      Shah Rukh Khan
# Aankhen (2002 film)       Amitabh Bachchan
# Saathiya (film)               Vivek Oberoi
# Company (film)                  Ajay Devgn
# Awara Paagal Deewana          Akshay Kumar
# Name: lead, dtype: object

# %%
# from virat kohli csv file
print(vk.tail())
print(vk.tail(10))  # last 10 matches
# Out:
# match_no
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64
# match_no
# 206     0
# 207     0
# 208     9
# 209    58
# 210    30
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
# sample ( randomly one  value return  )
# random selected ( use - when we use sample randomly )
print(vk.sample())
print(vk.sample(5))
# Out:
# match_no
# 151    39
# Name: runs, dtype: int64
# match_no
# 89     21
# 159    23
# 83     17
# 146    30
# 67      3
# Name: runs, dtype: int64

# %%
# value_counts -> movies
# ques - how many movies done by a actor
# frequency using ( values_count) in descending order

print(movies.value_counts())
# Out:
# lead
# Akshay Kumar         48
# Amitabh Bachchan     45
# Ajay Devgn           38
# Salman Khan          31
# Sanjay Dutt          26
#                      ..
# Seema Azmi            1
# Akanksha Puri         1
# Charanpreet Insan     1
# Jaideep Ahlawat       1
# Monali Thakur         1
# Name: count, Length: 566, dtype: int64

# %%
print(vk.value_counts())
# Out:
# runs
# 0     9
# 1     8
# 12    8
# 9     7
# 8     6
#      ..
# 46    1
# 29    1
# 84    1
# 90    1
# 53    1
# Name: count, Length: 78, dtype: int64

# %%
# sort-values ( method)
# ques- virat kohli ipl highest score (ascending order)
# ans- 128 match virat kohli scores 113 runs (values)

print(vk.sort_values())
# Out:
# match_no
# 8        0
# 87       0
# 93       0
# 91       0
# 206      0
#       ...
# 164    100
# 120    100
# 123    108
# 126    109
# 128    113
# Name: runs, Length: 215, dtype: int64

# %%
# also sort in descending order



vk.sort_values(ascending=False)


# but we need head top most then head (1)


print(vk.sort_values(ascending=False).head(1).values[0])




# .values return ( runs print only ( 128 match numberr and runs are the  values ))
# numpy array return  .values
# .values[0] -->> only value not array


# -->>> This method is called method chainig one method after another method
# Out:
# 113

# %% [markdown]
# Sort method is temporary changes not permanent original is same
# we can change it permanently
# in original
# inplace=True ( no output it changes permanent )

# %%
vk
print(vk.sort_values(ascending=False)) # permanent changes

#vk.sort_values(inplace=True)
# Out:
# match_no
# 128    113
# 126    109
# 123    108
# 120    100
# 164    100
#       ...
# 93       0
# 130      0
# 206      0
# 207      0
# 211      0
# Name: runs, Length: 215, dtype: int64

# %% [markdown]
# IN - place parameter changes permanent

# %%
# Next method -- sort_index ( work on index )
movies

# here index are not well orgainsed (if alphabetically arranged ? )

movies.sort_index().head()

print(movies.sort_index(ascending=False)) # descending order (false)


# note ->> Here also inplace = True paramter that changes permanent
# Out:
# movie
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Zokkomon                       Darsheel Safary
# Zindagi Tere Naam           Mithun Chakraborty
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi 50-50                      Veena Malik
#                                    ...
# 2 States (2014 film)              Arjun Kapoor
# 1971 (2007 film)                Manoj Bajpayee
# 1920: The Evil Returns             Vicky Ahuja
# 1920: London                     Sharman Joshi
# 1920 (film)                   Rajniesh Duggall
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# ```
# # Series Maths Methods
# ```

# %%
# count (not count missing values but size count missing values )
# count total no of items return in a series

print(vk.count()) # 215 matches play by virat kohli


# NOT count nan missing vlaues count method
# Out:
# 215

# %%
# sum and prod
# ques - subs gain in one year we have data as name as subs
s
print(s.sum()) # total sum suscriber gained

print(s.product()) # 0 means in betwen data a zero

# sum and prodcut
# Out:
# 49510
# 0

# %%
# statiscial method
# mean -- median --mode -- std -- var

print(s.mean()) # daily gain

# virat kohli score in ipl innings ( median)

print(vk.median())  # 24


# mode ( mode mean valuue that comes many times in an data )

# movies actor name returrn


print(movies.mode()) # akshay kumar ( frequent item in our series )


# std
print(s.std())


# var
print(vk.var())
# Out:
# 135.64383561643837
# 24.0
# 0    Akshay Kumar
# Name: lead, dtype: object
# 62.67502303725269
# 688.0024777222344

# %%
# Max and min method in pandas ( series )
# ques - maximum no of subscibers gained in year in one day
s.min()
s.max()
# Out:
# 396

# %%
# describe -- provides a summary
vk.describe()


# summary all mathematical quantities
# count - 215 not null values mean - average is 30
# min - 0 25% inning 9 least score 9
# in 75 percent ining 24 runs high or least he score


# most method
# Out:
# count    215.000000
# mean      30.855814
# std       26.229801
# min        0.000000
# 25%        9.000000
# 50%       24.000000
# 75%       48.000000
# max      113.000000
# Name: runs, dtype: float64

# %%
s.describe()
# Out:
# count    365.000000
# mean     135.643836
# std       62.675023
# min       33.000000
# 25%       88.000000
# 50%      123.000000
# 75%      177.000000
# max      396.000000
# Name: Subscribers gained, dtype: float64

# %%
movies.describe()
# Out:
# count             1500
# unique             566
# top       Akshay Kumar
# freq                48
# Name: lead, dtype: object

# %%
# Series indexing
# integer indexing
x = pd.Series([12,12,14,34,5,67,67,65,43,34,45])
x[0]
x[1]
# Out:
# np.int64(12)

# %%
# negative indexing --not work
# series work on postive indexing

# %%
movies
# here indexing not work
print(movies)

print(movies['Battalion 609']) # index number battalon 609 movies name here
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object
# Vicky Ahuja

# %%
marks
# number not work negative indexing string workking
# Out:
# {'deepanshu': 56, 'Himanshu': 56, 'vishal': 65}

# %%
# slicing - at one time multiple item fetch
print(vk[5:16])
# Out:
# match_no
# 6      9
# 7     34
# 8      0
# 9     21
# 10     3
# 11    10
# 12    38
# 13     3
# 14    11
# 15    50
# 16     2
# Name: runs, dtype: int64

# %%
# negative slicing
print(vk[-5:])
# Out:
# match_no
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
# slicing for movies
print(movies[-5:]) #last 5 movies
# Out:
# movie
# Hum Tumhare Hain Sanam      Shah Rukh Khan
# Aankhen (2002 film)       Amitabh Bachchan
# Saathiya (film)               Vivek Oberoi
# Company (film)                  Ajay Devgn
# Awara Paagal Deewana          Akshay Kumar
# Name: lead, dtype: object
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# The Accidental Prime Minister (film)         Anupam Kher
# Evening Shadows                         Mona Ambegaonkar
# Fraud Saiyaan                               Arshad Warsi
# Manikarnika: The Queen of Jhansi          Kangana Ranaut
#                                               ...
# Raaz (2002 film)                              Dino Morea
# Waisa Bhi Hota Hai Part II                  Arshad Warsi
# Kaante                                  Amitabh Bachchan
# Aankhen (2002 film)                     Amitabh Bachchan
# Company (film)                                Ajay Devgn
# Name: lead, Length: 750, dtype: object

# %%
print(movies[::2]) # step of 2
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# The Accidental Prime Minister (film)         Anupam Kher
# Evening Shadows                         Mona Ambegaonkar
# Fraud Saiyaan                               Arshad Warsi
# Manikarnika: The Queen of Jhansi          Kangana Ranaut
#                                               ...
# Raaz (2002 film)                              Dino Morea
# Waisa Bhi Hota Hai Part II                  Arshad Warsi
# Kaante                                  Amitabh Bachchan
# Aankhen (2002 film)                     Amitabh Bachchan
# Company (film)                                Ajay Devgn
# Name: lead, Length: 750, dtype: object

# %%
# fancy indexing
 # ques- runs scoree by viratkohli in 1345
print(vk[[1,3,4,5]]) # double round brackets
# Out:
# match_no
# 1     1
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
# indexing with labels -> fancy indexing

# label means we provide custom index so acces thier value

movies['Evening Shadows']
# Out:
# 'Mona Ambegaonkar'

# %% [markdown]
# Editing Series

# %%
# how can we edit items inside in the series
# using indexing
runs
df=pd.Series((runs))
print(df)

# runs upgrrade  using indexing
df[1]=34
print(df)
# Out:
# 0     13
# 1     24
# 2     56
# 3     78
# 4    100
# dtype: int64
# 0     13
# 1     34
# 2     56
# 3     78
# 4    100
# dtype: int64

# %%
# what if an index does not exist
df[5]=56    # a new item added

# %%
# slicing - using slicing also edit series
# muultiple item also edit
df
df[2:4]=[100,100]
df
# Out:
# 0     13
# 1     34
# 2    100
# 3    100
# 4    100
# 5     56
# dtype: int64

# %%
# fancy indexing
df[[0,3,4]]=[0,0,0]
df
# Out:
# 0      0
# 1     34
# 2    100
# 3      0
# 4      0
# 5     56
# dtype: int64

# %%
# using index label
movies['Hum Tumhare Hain Sana']='salman khan'
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Hum Tumhare Hain Sana                        salman khan
# Name: lead, Length: 1501, dtype: object

# %% [markdown]
# Mostly read data in padnas not write but we have feature to write edit

# %%
# copy and view topic ( sup vid)

# %% [markdown]
# Series with Python FUnctionalities

# %%
# len type sorted max min
# python functions that we can usse in series in pandas
print(len(s)) # total subscribers
print(type(s)) # series
print(dir(s)) # attributes method return
print(sorted(s))
print(max(s))
print(min(s))
# Out:
# 365
# <class 'pandas.core.series.Series'>
# ...

# %%
# type coversion llist - dictioanry - list
list(marks)
# Out:
# ['deepanshu', 'Himanshu', 'vishal']

# %%
dict(marks)
# Out:
# {'deepanshu': 56, 'Himanshu': 56, 'vishal': 65}

# %%
# membership operator  in and not
# lets take movies dataset
movies
'Aankhen (2002 film)' in movies
# Out:
# True

# %%
movies
'Alia Bhatt ' in movies.values
# Out:
# False

# %% [markdown]
# Note - membership operator work only in item not values using .values in operator work

# %%
#looping
# index in index and items for index for i in movies.index (.index)
for i in movies.index:
  print(i)
# Out:
# Uri: The Surgical Strike
# Battalion 609
# The Accidental Prime Minister (film)
# Why Cheat India
# Evening Shadows
# Soni (film)
# Fraud Saiyaan
# Bombairiya
# Manikarnika: The Queen of Jhansi
# Thackeray (film)
# Amavas
# Gully Boy
# Hum Chaar
# Total Dhamaal
# Sonchiriya
# Badla (2019 film)
# Mard Ko Dard Nahi Hota
# Hamid (film)
# Photograph (film)
# Risknamaa
# Mere Pyare Prime Minister
# 22 Yards
# Kesari (film)
# Notebook (2019 film)
# Junglee (2019 film)
# Gone Kesh
# Albert Pinto Ko Gussa Kyun Aata Hai?
# The Tashkent Files
# Kalank
# Setters (film)
# Student of the Year 2
# PM Narendra Modi
# De De Pyaar De
# India's Most Wanted (film)
# Yeh Hai India
# Khamoshi (2019 film)
# Kabir Singh
# Article 15 (film)
# One Day: Justice Delivered
# Hume Tumse Pyaar Kitna
# Super 30 (film)
# Family of Thakurganj
# Batla House
# Jhootha Kahin Ka
# Judgementall Hai Kya
# Chicken Curry Law
# Arjun Patiala
# Jabariya Jodi
# Pranaam
# The Sky Is Pink
# Mission Mangal
# Saaho
# ...

# %%
# Arithmethic operators  also ( broadcasting )

# 100 + runs

# %%
# relational  operator
# bollean series return
vk>=50
# Out:
# match_no
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 211    False
# 212    False
# 213     True
# 214    False
# 215    False
# Name: runs, Length: 215, dtype: bool

# %%
# bollean indexing on series
# find no of 50s and 100s scored by kohli
vk[vk>=50] # filter data
vk[vk>=50].size
# Out:
# 50

# %%
# FInd number of ducks ( 0 )
vk == 0
vk[vk==0]
# Out:
# match_no
# 8      0
# 87     0
# 91     0
# 93     0
# 130    0
# 135    0
# 206    0
# 207    0
# 211    0
# Name: runs, dtype: int64

# %%
# example -- from subscriber csv in which which day more than 200 subscibers i gained
s[s>200]
print(s[s>200].size) # 59 days more than 200 subscribers gained
# Out:
# 59

# %%
# find actors who have done more than 20 movies
num=movies.value_counts()
num[num>20]
# num variable telling us actor that do how many movies
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %%
# Plotting Graphs on Series # it show 2d bar on the time o plotting

# ques- pandas is so ppowerful can plot graphs
# 365 days subscriber gained plot graph day by day
s.plot()
# Out:
# <Axes: >

# %%
# ques- which actor make movies

# top 20 actor that make more than 20 movies

# movies.value_counts().head(20).plot(kind='bar)
num=movies.value_counts().head(20)
num.plot(kind='bar')
# Out:
# <Axes: xlabel='lead'>

# %%
# some important series methods (next video )
# agg
# astype
# between
# clip
# dropna
# fillna
#filter
#iloc
#isnull
#map
#filter
