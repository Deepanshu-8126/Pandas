# %% [markdown]
# Array in Python

# %%
arr = [10,20,30,40]
for x in arr:
    print(x)
 # travesal
# Out:
# 10
# 20
# 30
# 40

# %%
arr = [10,20.30,40]
for x in arr:
    if x>20:
        print(x)
# Out:
# 20.3
# 40

# %%
# sum  of array 
# average of array # producct of array
for _ in arr:
    print(x)
# Out:
# 40
# 40
# 40
# 40
