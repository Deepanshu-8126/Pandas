# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepanshu-8126/Pandas/blob/main/pandas_dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pandas DataFrame

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Create a dataframe

# %%
# using lists
# 2d lists using
# iq marks lpa data in the form
student_data=[[100,80,10],
              [90,70,7],
              [120,100,14],
              [80,50,2]]
a=pd.DataFrame(student_data,columns=['iq','marks','package'])
print(a)
print(type(a))
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2
# <class 'pandas.core.frame.DataFrame'>

# %%
# using dict creating dataframe
student_dict={
  "iq":[100,90,120,80],
  "marks":[80,70,100,50],
  "package":[10,7,14,2]
}
pd.DataFrame(student_dict)
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2

# %%
# using read_csv

movies=pd.read_csv('/content/movies.csv')

# %%
# Second dataset

ipl=pd.read_csv('/content/ipl-matches.csv')
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %% [markdown]
# Dataframe methods / attributes

# %%
# shape
# --> shape tells us how many rows and columns in our dataset
# i want to check for movies dataset
print(movies.shape)
print(ipl.shape)
# Out:
# (1629, 18)
# (950, 20)

# %%
# dtypes -- (since in dataframe mulitple column of series a personal datatype )
# notee - in pandas object as string

# for all column differrnt dtype
movies.dtypes
ipl.dtypes
# Out:
# ID                   int64
# City                object
# Date                object
# Season              object
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# Player_of_Match     object
# Team1Players        object
# Team2Players        object
# Umpire1             object
# Umpire2             object
# dtype: object

# %%
# index ( dataframe index also )
print(movies.index)
print(ipl.index)
# Out:
# RangeIndex(start=0, stop=1629, step=1)
# RangeIndex(start=0, stop=950, step=1)

# %%
# columns
# means return all columns in our dataset return in index  object  )
# inside a 2d array
print(movies.columns)
print(ipl.columns) # for ipl dataset
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
# values
a.values # student data
ipl.values
# Out:
# array([[1312200, 'Ahmedabad', '2022-05-29', ...,
#         "['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pandya', 'DA Miller', 'R Tewatia', 'Rashid Khan', 'R Sai Kishore', 'LH Ferguson', 'Yash Dayal', 'Mohammed Shami']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312199, 'Ahmedabad', '2022-05-27', ...,
#         "['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D Padikkal', 'SO Hetmyer', 'R Parag', 'R Ashwin', 'TA Boult', 'YS Chahal', 'M Prasidh Krishna', 'OC McCoy']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312198, 'Kolkata', '2022-05-25', ...,
#         "['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda', 'MP Stoinis', 'E Lewis', 'KH Pandya', 'PVD Chameera', 'Mohsin Khan', 'Avesh Khan', 'Ravi Bishnoi']",
#         'J Madanagopal', 'MA Gough'],
#        ...,
#        [335984, 'Delhi', '2008-04-19', ...,
#         "['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif', 'DS Lehmann', 'RA Jadeja', 'M Rawat', 'D Salunkhe', 'SK Warne', 'SK Trivedi', 'MM Patel']",
# ...

# %%
# head (functions) means preview data
movies.head(6) # top 5 movies from the datset
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
# 5                           Soni (film)  tt6078866
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
# 5  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# ...

# %%
# tail
movies.tail(4)
# Out:
#                    title_x     imdb_id  \
# 1625  Yeh Zindagi Ka Safar   tt0298607
# 1626       Sabse Bada Sukh   tt0069204
# 1627                 Daaka  tt10833860
# 1628              Humsafar   tt2403201
#
#                                             poster_path  \
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# 1626                                                NaN
# 1627  https://upload.wikimedia.org/wikipedia/en/thum...
# 1628  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link               title_y  \
# 1625  https://en.wikipedia.org/wiki/Yeh_Zindagi_Ka_S...  Yeh Zindagi Ka Safar
# 1626      https://en.wikipedia.org/wiki/Sabse_Bada_Sukh       Sabse Bada Sukh
# 1627                https://en.wikipedia.org/wiki/Daaka                 Daaka
# 1628             https://en.wikipedia.org/wiki/Humsafar              Humsafar
#
#             original_title  is_adult  year_of_release runtime         genres  \
# ...

# %%
# another example taking data from another dataset
ipl.tail(6)
# Out:
#          ID        City        Date   Season MatchNumber  \
# 944  335987      Jaipur  2008-04-21  2007/08           6
# 945  335986     Kolkata  2008-04-20  2007/08           4
# 946  335985      Mumbai  2008-04-20  2007/08           5
# 947  335984       Delhi  2008-04-19  2007/08           3
# 948  335983  Chandigarh  2008-04-19  2007/08           2
# 949  335982   Bangalore  2008-04-18  2007/08           1
#
#                            Team1                        Team2  \
# 944             Rajasthan Royals              Kings XI Punjab
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# ...

# %%
# sample - random one row return bais
movies.sample()
# Out:
#                      title_x    imdb_id  \
# 507  Machhli Jal Ki Rani Hai  tt2208248
#
#                                            poster_path  \
# 507  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                              wiki_link  \
# 507  https://en.wikipedia.org/wiki/Machhli_Jal_Ki_R...
#
#                      title_y           original_title  is_adult  \
# 507  Machhli Jal Ki Rani Hai  Machhli Jal Ki Rani Hai         0
#
#      year_of_release runtime  genres  imdb_rating  imdb_votes  \
# 507             2014     120  Horror          2.7         136
#
#                                                  story  \
# 507  Ayesha and Uday Saxena are a happily married c...
#
#                                                summary tagline  \
# 507  It's not just a matter of one spirit  it's a m...     NaN
#
#                                                 actors wins_nominations  \
# ...

# %%
# info ( high level information provide )
movies.info()

# 1629 but some places missing
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
ipl.info()
# info method is very useful if importing any dataset it tells mising data dtype
# at one time
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
# next function - describe ( as work summary given dne  ey)
# numerical columns only in output

movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
ipl.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
# one more important functions isnull
# .sum apply in null so add 1 +1 missing value


movies.isnull().sum()

# using .sum that tells in columns how many missing values in an column

# return boolean values true or false where true tell missing value
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
# Next --> duplicated function
# that tells how many duplicates in our dataframe

movies.duplicated()  # return boolean false means there is no duplicate item in our dataframe
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1624    False
# 1625    False
# 1626    False
# 1627    False
# 1628    False
# Length: 1629, dtype: bool

# %%
student_dict={
  "iq":[100,90,120,80,0,0],
  "marks":[80,70,100,50,0,0],
  "package":[10,7,14,2,0,0]
}
students=pd.DataFrame(student_dict)
print(students)

# lets check in any column any duplicated item / value
print(students.duplicated().sum()) # 1 item is duplicated
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2
# 4    0      0        0
# 5    0      0        0
# 1

# %%
# rename ( marks - change - percent and package change to - lpa )
# using columns
# column parameter ( old value and new value )


# note that are not permanent change original student data is as it is

# inplace = true permanent change
students.rename(columns={'marks':'percent','package':'lpa'},inplace=True)
print(students)
# Out:
#     iq  percent  lpa
# 0  100       80   10
# 1   90       70    7
# 2  120      100   14
# 3   80       50    2
# 4    0        0    0
# 5    0        0    0

# %%
# Mathematical functions
# sum mean median axis argument -- automatically do sum at every column
students.sum() # total sum of all columns
print(students)
# rows also aply
students.sum(axis=1)

# this axis parameter is applicable for all mathematical functions
# like mean , median etc
# Out:
#     iq  percent  lpa
# 0  100       80   10
# 1   90       70    7
# 2  120      100   14
# 3   80       50    2
# 4    0        0    0
# 5    0        0    0
# 0    190
# 1    167
# 2    234
# 3    132
# 4      0
# 5      0
# dtype: int64

# %%
students.mean()
students.min() # default here column wise minimum
students.min(1)
# Out:
# 0    10
# 1     7
# 2    14
# 3     2
# 4     0
# 5     0
# dtype: int64

# %%
students.max()
students.median()
students.std()
students.var()

# same as in series but here both axis operation perform row wise sum etc
# Out:
# iq         2710.0
# percent    1760.0
# lpa          33.5
# dtype: float64

# %% [markdown]
# Selecting cols from a Dataframe

# %%
# single column
# from movies dataset we need only movie name column single column fetch
movies['title_x'].head()

# type (is series )
print(type(movies['title_x'])) # series return class
# Out:
# <class 'pandas.core.series.Series'>

# %%
# another dataset ipl
# task - venue column

ipl['Venue']

print(ipl['Venue'].head(5)) # top 5
# Out:
# 0    Narendra Modi Stadium, Ahmedabad
# 1    Narendra Modi Stadium, Ahmedabad
# 2               Eden Gardens, Kolkata
# 3               Eden Gardens, Kolkata
# 4            Wankhede Stadium, Mumbai
# Name: Venue, dtype: object

# %%
# muliple columns
# --> title actors year of release

# for need of multiple columns use fancy indexing

movies[['title_x','year_of_release','actors']]

# this is dataframe
# order can decide rearrange order we can decide
# -----movies[['year_of_release','actors','title_x']]
# Out:
#                                    title_x  year_of_release  \
# 0                 Uri: The Surgical Strike             2019
# 1                            Battalion 609             2019
# 2     The Accidental Prime Minister (film)             2019
# 3                          Why Cheat India             2019
# 4                          Evening Shadows             2018
# ...                                    ...              ...
# 1624                 Tera Mera Saath Rahen             2001
# 1625                  Yeh Zindagi Ka Safar             2001
# 1626                       Sabse Bada Sukh             2018
# 1627                                 Daaka             2019
# 1628                              Humsafar             2011
#
#                                                  actors
# 0     Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...
# 1     Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...
# 2     Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...
# ...

# %%
# from ipl data particular column
# particular fetch multiple columns -- dataframe
ipl[['Team1','Team2','WinningTeam']].head((5))
# Out:
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                    WinningTeam
# 0               Gujarat Titans
# 1             Rajasthan Royals
# 2  Royal Challengers Bangalore
# 3               Gujarat Titans
# 4                 Punjab Kings

# %%
# example of student dictionary
student_dict={
  'name':['nitin','ankit','rupesh','risabh','amit','ankita'],
  "iq":[100,90,120,80,0,0],
  "marks":[80,70,100,50,0,0],
  "package":[10,7,14,2,0,0]
}

# any column serve as an index
# example --- using set_index
students=pd.DataFrame(student_dict)
print(students)
students.set_index('name',inplace=True) # inplace true permanent change
# Out:
#      name   iq  marks  package
# 0   nitin  100     80       10
# 1   ankit   90     70        7
# 2  rupesh  120    100       14
# 3  risabh   80     50        2
# 4    amit    0      0        0
# 5  ankita    0      0        0

# %% [markdown]
# How to fetch rows

# %%
# selecting from a dataframe
# iloc - searches using index positions
# loc - searches using index label
movies.iloc[0]
movies.iloc[1]
# single row fetch using iloc function
# Out:
# title_x                                                 Battalion 609
# imdb_id                                                     tt9472208
# poster_path                                                       NaN
# wiki_link                 https://en.wikipedia.org/wiki/Battalion_609
# title_y                                                 Battalion 609
# original_title                                          Battalion 609
# is_adult                                                            0
# year_of_release                                                  2019
# runtime                                                           131
# genres                                                            War
# imdb_rating                                                       4.1
# imdb_votes                                                         73
# story               The story revolves around a cricket match betw...
# ...

# %%
# mulitple row fetch ( slicing )
movies.iloc[0:5]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
# step of 2
movies.iloc[5:10:2]
# Out:
#             title_x    imdb_id  \
# 5       Soni (film)  tt6078866
# 7        Bombairiya  tt4971258
# 9  Thackeray (film)  tt7777196
#
#                                          poster_path  \
# 5  https://upload.wikimedia.org/wikipedia/en/thum...
# 7  https://upload.wikimedia.org/wikipedia/en/thum...
# 9  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                         wiki_link     title_y original_title  \
# 5       https://en.wikipedia.org/wiki/Soni_(film)        Soni           Soni
# 7        https://en.wikipedia.org/wiki/Bombairiya  Bombairiya     Bombairiya
# 9  https://en.wikipedia.org/wiki/Thackeray_(film)   Thackeray      Thackeray
#
#    is_adult  year_of_release runtime              genres  imdb_rating  \
# 5         0             2018      97               Drama          7.2
# 7         0             2019     104  Comedy|Crime|Drama          4.3
# 9         0             2019     120     Biography|Drama          5.1
#
# ...

# %%
# fancy indexing ( list behind )
movies.iloc[[0,4,5]]
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 4           Evening Shadows  tt6028796
# 5               Soni (film)  tt6078866
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
# 5  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
# 5          https://en.wikipedia.org/wiki/Soni_(film)
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 4           Evening Shadows           Evening Shadows         0
# 5                      Soni                      Soni         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# ...

# %% [markdown]
# Note - iloc index position using fetch data row retun

# %%
#loc ( label use )
print(students)
# Out:
#          iq  marks  package
# name
# nitin   100     80       10
# ankit    90     70        7
# rupesh  120    100       14
# risabh   80     50        2
# amit      0      0        0
# ankita    0      0        0

# %%
# for one item
students.loc['nitin']
# Out:
# iq         100
# marks       80
# package     10
# Name: nitin, dtype: int64

# %%
# for multiple items (slicing )
# slicing
students.loc['nitin':'risabh']
# Out:
#          iq  marks  package
# name
# nitin   100     80       10
# ankit    90     70        7
# rupesh  120    100       14
# risabh   80     50        2

# %%
# fancy indexing
students.loc[['nitin','ankita','rupesh']]
# Out:
#          iq  marks  package
# name
# nitin   100     80       10
# ankita    0      0        0
# rupesh  120    100       14

# %%
# iloc
students.iloc[0]
# Out:
# iq         100
# marks       80
# package     10
# Name: nitin, dtype: int64

# %%
students.iloc[0:5:2]
# fancy indexing also iloc
# Out:
#          iq  marks  package
# name
# nitin   100     80       10
# rupesh  120    100       14
# amit      0      0        0

# %%
students.iloc[[0,5,2]] # pass list inside list
# this is using label
# Out:
#          iq  marks  package
# name
# nitin   100     80       10
# ankita    0      0        0
# rupesh  120    100       14

# %%
# Selectiing both rows and cols fetch
# first three movies i need
# filtering both in rows and columns
movies.iloc[0:3,0:3] # rows , cols
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %%
movies.loc[0:2,'title_x':'poster_path'] # here index and also columns
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %% [markdown]
# iloc index use -- provide index positoon loc - provide name
# internally manage -- loc using

# %% [markdown]
# How to fetch single row , col multiple col , single row col both we learned

# %%
# FILTERING DATA
ipl.head(2) # first 2 matches

# find all the final winners
# final matchs

mask=ipl['MatchNumber'] == 'Final'
new_df=ipl[mask]
# from new_df
new_df[['Season','WinningTeam']] # two cols
# fancy indexing

# one liner code
ipl[ipl['MatchNumber']=='Final'][['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
# ques - how many superover finishes have occured (nno of matches )
# --> two teams make same runs
ipl[ipl['SuperOver'] =='Y'].shape[0] # no of rows index[0]  --14 times
# Out:
# 14

# %%
# ques - how many matches has csk won  in kolkata
ipl.head(2) # what we have to filter city
ipl[(ipl['City']=='Kolkata') & (ipl['WinningTeam']=='Chennai Super Kings')].shape[0] # 5 matches csk won in kolkata
# total matches .shape rows find
# Out:
# 5

# %%
# toss winner is match winner in percentage
# win match also toss also win ( 50 percent time the team won the toss that also win the match )
ipl
ipl[ipl['TossWinner']==ipl['WinningTeam']]
ipl[ipl['TossWinner']==ipl['WinningTeam']].shape[0] # 489 matches

(ipl[ipl['TossWinner']==ipl['WinningTeam']].shape[0]/ipl.shape[0])*100
# Out:
# 51.473684210526315
