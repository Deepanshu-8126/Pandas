# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepanshu-8126/Pandas/blob/main/pandas_dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Create a dataframe

# %%
# using lists
# 2d lists using
# iq marks lpa data in the form
student_data=[[100,80,10],
              [90,70,7],
              [120,100,14],
              [80,50,2]]
a=pd.DataFrame(student_data,columns=['iq','marks','package'])
print(a)
print(type(a))
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2
# <class 'pandas.core.frame.DataFrame'>

# %%
# using dict creating dataframe
student_dict={
  "iq":[100,90,120,80],
  "marks":[80,70,100,50],
  "package":[10,7,14,2]
}
pd.DataFrame(student_dict)
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2

# %%
# using read_csv
movies=pd.read_csv('/content/movies.csv')

# %%
# Second dataset
ipl=pd.read_csv('/content/ipl-matches.csv')
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %% [markdown]
# Dataframe methods / attributes

# %%
# shape
# --> shape tells us how many rows and columns in our dataset
# i want to check for movies dataset
print(movies.shape)
print(ipl.shape)
# Out:
# (1629, 18)
# (950, 20)

# %%
# dtypes -- (since in dataframe mulitple column of series a personal datatype )
# notee - in pandas object as string

# for all column differrnt dtype
movies.dtypes
ipl.dtypes
# Out:
# ID                   int64
# City                object
# Date                object
# Season              object
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# Player_of_Match     object
# Team1Players        object
# Team2Players        object
# Umpire1             object
# Umpire2             object
# dtype: object

# %%
# index ( dataframe index also )
print(movies.index)
print(ipl.index)
# Out:
# RangeIndex(start=0, stop=1629, step=1)
# RangeIndex(start=0, stop=950, step=1)

# %%
# columns
# means return all columns in our dataset return in index  object )
print(movies.columns)
print(ipl.columns) # for ipl dataset
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')
